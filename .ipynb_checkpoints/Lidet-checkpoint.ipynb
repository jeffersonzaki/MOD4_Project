# %% [markdown]
# # Cleaning Notebook

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score, train_test_split

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import folium

# %%
#2017 DATA 

#Selecting rows for regression analysis from the dataset
df = pd.read_csv('/Users/lidetalemu/Downloads/the-human-freedom-index/hfi_cc_2019.csv')

df_2017 = df[['year', 'countries', 'hf_score', 'pf_rol', 'pf_ss', 'pf_movement','pf_religion', 'pf_association',
        'pf_expression', 'pf_identity', 'ef_government', 'ef_legal', 'ef_money', 'ef_trade', 'ef_trade_movement_foreign']]

#selecting 2017 only data

df_2017 = df.loc[df_2017['year'] ==  2017]

#Dropping rows with Null values

missing_values = df_2017.loc[df_2017.pf_association == '-']
df_2017 = df_2017.drop(index=missing_values.index)

# %%
df_2017 = df_2017.drop(columns=['region','ISO_code', 'year'], axis=1)

df_2017.head()
# Out:
#    countries hf_score hf_rank hf_quartile pf_rol_procedural pf_rol_civil  \
# 0    Albania     7.84      38           1               6.7          4.5
# 1    Algeria     4.99     155           4                 -            -
# 2     Angola      5.4     151           4                 -            -
# 3  Argentina     6.86      77           2               7.1          5.8
# 4    Armenia     7.42      54           2                 -            -
#
#   pf_rol_criminal pf_rol pf_ss_homicide pf_ss_disappearances_disap  ...  \
# 0             4.7    5.3            9.1                         10  ...
# 1               -    3.8            9.5                         10  ...
# 2               -    3.4            8.1                         10  ...
# 3             4.3    5.7              8                          5  ...
# 4               -    4.9              9                         10  ...
#
#   ef_regulation_business_adm ef_regulation_business_bureaucracy  \
# 0                        6.3                                6.7
# 1                        3.7                                1.8
# 2                        2.4                                1.3
# 3                        2.5                                7.1
# 4                        4.6                                6.2
#
#   ef_regulation_business_start ef_regulation_business_bribes  \
# 0                          9.7                           4.1
# 1                          9.3                           3.8
# 2                          8.7                           1.9
# 3                          9.6                           3.3
# 4                          9.9                           4.6
#
#   ef_regulation_business_licensing ef_regulation_business_compliance  \
# 0                                6                               7.2
# 1                              8.7                                 7
# 2                              8.1                               6.8
# 3                              5.4                               6.5
# 4                              9.3                               7.1
#
#   ef_regulation_business ef_regulation ef_score ef_rank
# 0                    6.7           7.8     7.67      30
# 1                    5.7           5.4     4.77     159
# 2                    4.9           5.7     4.83     158
# 3                    5.7           5.6     5.67     147
# 4                    6.9           7.5      7.7      27
#
# [5 rows x 117 columns]

# %%
#dropping columns not necessary for regression analysis.

df_2017= df_2017[['hf_score', 'pf_rol', 'pf_ss', 'pf_movement','pf_religion', 'pf_association',
            'pf_expression', 'pf_identity', 'ef_government', 'ef_legal', 'ef_money',
             'ef_trade', 'ef_trade_regulatory']]

# %%
# Changing data types to float
df_2017 = df_2017.astype(float)

# %%
df_2017['total_personal'] = df_2017[['pf_religion', 'pf_movement', 'pf_association','pf_expression', 'pf_identity']].values.mean(axis=1)

# %%
df_2017['total_political'] = df_2017[['pf_rol', 'pf_ss', 'ef_government', 'ef_legal']].values.mean(axis=1)

# %%
df_2017['total_economic'] = df_2017[['ef_money', 'ef_trade_regulatory', 'ef_trade']].values.mean(axis=1)

# %%
df_total = df_2017[['hf_score', 'total_personal', 'total_political', 'total_economic']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1395-8c57747e01de> in <module>
# ----> 1 df_total = df_2017[['hf_score', 'total_personal', 'total_political', 'total_economic']]
#       2
#       3
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1549
#    1550         self._validate_read_indexer(
# -> 1551             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1552         )
#    1553         return keyarr, indexer
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1642             if not (self.name == "loc" and not raise_missing):
#    1643                 not_found = list(set(key) - set(ax))
# -> 1644                 raise KeyError(f"{not_found} not in index")
#    1645
#    1646             # we skip the warning on Categorical/Interval
#
# KeyError: "['total_personal'] not in index"

# %%
import statsmodels.api as sm

X = df_total.drop(columns='hf_score').values

y = df_total.hf_score

x_col = list(df_total.drop(columns='hf_score').columns)
# Fitting the actual model

X = sm.add_constant(X)
model = sm.OLS(y, X, hasconst=True )

result = model.fit()

labels = ['intercept'] + x_col

result.summary(xname=labels)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               hf_score   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                     6052.
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):          4.15e-141
# Time:                        16:29:06   Log-Likelihood:                 126.49
# No. Observations:                 136   AIC:                            -245.0
# Df Residuals:                     132   BIC:                            -233.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# intercept           0.5209      0.051     10.283      0.000       0.421       0.621
# total_personal      0.2409      0.006     43.394      0.000       0.230       0.252
# total_political     0.5018      0.014     35.313      0.000       0.474       0.530
# total_economic      0.2082      0.010     19.906      0.000       0.188       0.229
# ==============================================================================
# Omnibus:                       15.910   Durbin-Watson:                   2.056
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               54.116
# Skew:                          -0.195   Prob(JB):                     1.77e-12
# Kurtosis:                       6.065   Cond. No.                         75.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y = df_total['hf_score']  # Dependent variable/target variable
X = df_total.drop(columns=['hf_score']) # Independent variables(features/predictors)


# Creating subsets/splitting data
X_train_total, X_test_total, y_train_total, y_test_total = train_test_split(X, y, random_state=42)

# %%
total_lr = LinearRegression()

# %%
total_lr.fit(X_train_total, y_train_total)

y_predict_total = total_lr.predict(X_train_total)

total_lr.score(X_train_total, y_train_total)
# Out:
# 0.9939110497949278

# %%
from sklearn.preprocessing import PolynomialFeatures


poly = PolynomialFeatures(degree= 2, interaction_only= True)

poly.fit(X_train_total)

X_interaction = poly.transform(X_train_total)

# %%
poly.get_feature_names()
# Out:
# ['1', 'x0', 'x1', 'x2', 'x0 x1', 'x0 x2', 'x1 x2']

# %%
lr_interaction = LinearRegression()

lr_interaction.fit(X_interaction, y_train_total)

y_interact = lr_interaction.predict(X_interaction)

# %%
res_interact = y_interact - y_train_total

# %%
plt.scatter(y_interact, res_interact)

# %%
## interaction terms with statsmodel

# %%
import statsmodels.api as sm




model = sm.OLS(y_train_total, X_interaction, hasconst=True )

result = model.fit()


result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               hf_score   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                     2898.
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):          3.09e-105
# Time:                        13:51:31   Log-Likelihood:                 103.41
# No. Observations:                 102   AIC:                            -192.8
# Df Residuals:                      95   BIC:                            -174.4
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1156      0.257     -0.450      0.654      -0.626       0.395
# x1             0.1998      0.043      4.623      0.000       0.114       0.286
# x2             0.5966      0.069      8.638      0.000       0.460       0.734
# x3             0.3563      0.056      6.409      0.000       0.246       0.467
# x4             0.0110      0.009      1.246      0.216      -0.006       0.028
# x5            -0.0026      0.006     -0.405      0.686      -0.015       0.010
# x6            -0.0238      0.008     -2.980      0.004      -0.040      -0.008
# ==============================================================================
# Omnibus:                        0.822   Durbin-Watson:                   2.335
# Prob(Omnibus):                  0.663   Jarque-Bera (JB):                0.387
# Skew:                          -0.076   Prob(JB):                        0.824
# Kurtosis:                       3.261   Cond. No.                     2.68e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.68e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X_train_total
# Out:
#      total_personal  total_political  total_economic
# 0              8.72            6.800        8.533333
# 119            7.84            5.650        7.400000
# 122            3.18            6.600        7.666667
# 30             6.28            4.875        4.733333
# 67             6.58            6.425        6.866667
# ..              ...              ...             ...
# 84             7.40            5.875        6.833333
# 124            5.94            5.700        7.366667
# 18             8.80            6.100        7.833333
# 109            6.38            5.200        5.800000
# 120            8.58            6.875        8.500000
#
# [102 rows x 3 columns]

# %%
sns.barplot()

# %%
poly.get_feature_names()
# Out:
# ['1', 'x0', 'x1', 'x2', 'x0 x1', 'x0 x2', 'x1 x2']

# %%
import statsmodels.api as sm


x_col = list(df_total.drop(columns='hf_score').columns)
# Fitting the actual model

X = sm.add_constant(X)
model = sm.OLS(y, X, hasconst=True )

result = model.fit()

labels = ['intercept'] + x_col

result.summary(xname=labels)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               hf_score   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                     6052.
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):          4.15e-141
# Time:                        16:06:01   Log-Likelihood:                 126.49
# No. Observations:                 136   AIC:                            -245.0
# Df Residuals:                     132   BIC:                            -233.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# intercept           0.5209      0.051     10.283      0.000       0.421       0.621
# total_personal      0.2409      0.006     43.394      0.000       0.230       0.252
# total_political     0.5018      0.014     35.313      0.000       0.474       0.530
# total_economic      0.2082      0.010     19.906      0.000       0.188       0.229
# ==============================================================================
# Omnibus:                       15.910   Durbin-Watson:                   2.056
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               54.116
# Skew:                          -0.195   Prob(JB):                     1.77e-12
# Kurtosis:                       6.065   Cond. No.                         75.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Grouping Dataframes by Polictical and Economic

# %% [markdown]
# ### Grouping by Political

# %%
# Function gets columns with chosen year
def year(df, year):
    return df.loc[df["year"] == year]

# %%
personal = df[['year','hf_score','pf_ss_women_fgm',
'pf_ss_women_inheritance_widows',
'pf_ss_women_inheritance_daughters',
'pf_ss_women_inheritance',
'pf_ss_women',
'pf_movement_domestic',
'pf_movement_foreign',
'pf_movement_women',
'pf_religion_estop_establish',
'pf_religion_estop_operate',
'pf_religion_estop',
'pf_religion_harassment',
'pf_religion_restrictions',
'pf_association_association',
'pf_association_assembly',
'pf_association_political_establish',
'pf_association_political_operate',
'pf_association_political',
'pf_association_prof_establish',
'pf_association_prof_operate',
'pf_association_prof',
'pf_association_sport_establish',
'pf_association_sport_operate',
'pf_association_sport',
'pf_expression_killed',
'pf_expression_jailed',
'pf_expression_influence',
'pf_expression_control',
'pf_expression_cable',
'pf_expression_newspapers',
'pf_expression_internet',
'pf_identity_legal',
'pf_identity_sex_male',
'pf_identity_sex_female',
'pf_identity_sex',
'pf_identity_divorce']]

"""
This is the main dataframe
for personal Freedom categories
"""
# Out:
# '\nThis is the main dataframe\nfor personal Freedom categories\n'

# %%
personal_2017 = year(personal, 2017) # Retrieving political data from 2017

# %%
personal_2017 = personal_2017.drop(columns=["year"])
personal_2017.head(2)
# Out:
#   hf_score pf_ss_women_fgm pf_ss_women_inheritance_widows  \
# 0     7.84              10                              -
# 1     4.99              10                              -
#
#   pf_ss_women_inheritance_daughters pf_ss_women_inheritance pf_ss_women  \
# 0                                 -                     7.5         8.8
# 1                                 -                       0           5
#
#   pf_movement_domestic pf_movement_foreign pf_movement_women  \
# 0                   10                  10                10
# 1                   10                   5               2.5
#
#   pf_religion_estop_establish  ... pf_expression_influence  \
# 0                           -  ...                       5
# 1                           -  ...                     2.7
#
#   pf_expression_control pf_expression_cable pf_expression_newspapers  \
# 0                   5.3                  10                       10
# 1                     4                  10                      7.5
#
#   pf_expression_internet pf_identity_legal pf_identity_sex_male  \
# 0                     10                 0                   10
# 1                    7.5                 -                    0
#
#   pf_identity_sex_female pf_identity_sex pf_identity_divorce
# 0                     10              10                 7.5
# 1                      0               0                   0
#
# [2 rows x 37 columns]

# %%
def drop_feature(df, features):
    return df.drop(columns=features)

# %%
personal_2017 = drop_feature(personal_2017, ['pf_ss_women_inheritance_widows', 'pf_ss_women_inheritance_daughters',
                                       'pf_religion_estop_establish', 'pf_religion_estop_operate', 
                                             'pf_expression_cable'])
personal_2017.head(2)
# Out:
#   hf_score pf_ss_women_fgm pf_ss_women_inheritance pf_ss_women  \
# 0     7.84              10                     7.5         8.8
# 1     4.99              10                       0           5
#
#   pf_movement_domestic pf_movement_foreign pf_movement_women  \
# 0                   10                  10                10
# 1                   10                   5               2.5
#
#   pf_religion_estop pf_religion_harassment pf_religion_restrictions  ...  \
# 0                10                    9.6                        8  ...
# 1                 5                    6.9                        3  ...
#
#   pf_expression_jailed pf_expression_influence pf_expression_control  \
# 0                   10                       5                   5.3
# 1                  9.5                     2.7                     4
#
#   pf_expression_newspapers pf_expression_internet pf_identity_legal  \
# 0                       10                     10                 0
# 1                      7.5                    7.5                 -
#
#   pf_identity_sex_male pf_identity_sex_female pf_identity_sex  \
# 0                   10                     10              10
# 1                    0                      0               0
#
#   pf_identity_divorce
# 0                 7.5
# 1                   0
#
# [2 rows x 32 columns]

# %%
def replace_with_na(df):
    for strings in df.values:
        df.replace('-', np.NaN, regex=True, inplace=True)

# %%
replace_with_na(personal_2017)
personal_2017
# Out:
#     hf_score pf_ss_women_fgm pf_ss_women_inheritance pf_ss_women  \
# 0       7.84              10                     7.5         8.8
# 1       4.99              10                       0           5
# 2        5.4              10                       5         7.5
# 3       6.86              10                      10          10
# 4       7.42              10                     7.5         8.8
# ..       ...             ...                     ...         ...
# 157      3.8              10                      10          10
# 158     6.29              10                     7.5         8.8
# 159      4.3             8.1                       0         4.1
# 160     6.49              10                       5         7.5
# 161     5.65              10                     7.5         8.8
#
#     pf_movement_domestic pf_movement_foreign pf_movement_women  \
# 0                     10                  10                10
# 1                     10                   5               2.5
# 2                      5                   5                10
# 3                     10                  10                10
# 4                     10                   5                10
# ..                   ...                 ...               ...
# 157                    0                  10                10
# 158                    0                   5                10
# 159                    0                   5                 0
# 160                    0                  10               2.5
# 161                    5                   5                10
#
#     pf_religion_estop pf_religion_harassment pf_religion_restrictions  ...  \
# 0                  10                    9.6                        8  ...
# 1                   5                    6.9                        3  ...
# 2                  10                    8.9                      7.5  ...
# 3                 7.5                      9                      6.9  ...
# 4                   5                    8.6                      5.1  ...
# ..                ...                    ...                      ...  ...
# 157                 5                      9                      6.6  ...
# 158               2.5                    8.6                      6.6  ...
# 159               NaN                    NaN                      NaN  ...
# 160               NaN                    8.3                      6.3  ...
# 161               2.5                    9.3                      7.5  ...
#
#     pf_expression_jailed pf_expression_influence  pf_expression_control  \
# 0                     10                       5                    5.3
# 1                    9.5                     2.7                      4
# 2                     10                     2.7                    2.5
# 3                     10                     5.7                    5.5
# 4                     10                     3.3                    4.3
# ..                   ...                     ...                    ...
# 157                  9.7                     1.3                    2.3
# 158                    9                       0                    1.8
# 159                   10                     1.3                      1
# 160                   10                     3.7                      4
# 161                   10                       2                    3.8
#
#      pf_expression_newspapers pf_expression_internet  pf_identity_legal  \
# 0                          10                     10                  0
# 1                         7.5                    7.5                NaN
# 2                           5                    7.5                 10
# 3                          10                     10                 10
# 4                         7.5                    7.5                  7
# ..                        ...                    ...                ...
# 157                       2.5                      5                  0
# 158                       7.5                      5                 10
# 159                       NaN                    NaN                NaN
# 160                       NaN                    NaN                 10
# 161                       NaN                    7.5                  0
#
#      pf_identity_sex_male pf_identity_sex_female  pf_identity_sex  \
# 0                      10                     10               10
# 1                       0                      0                0
# 2                       0                      0                0
# 3                      10                     10               10
# 4                      10                     10               10
# ..                    ...                    ...              ...
# 157                    10                     10               10
# 158                    10                     10               10
# 159                     0                      0                0
# 160                     0                      0                0
# 161                     0                     10                5
#
#      pf_identity_divorce
# 0                    7.5
# 1                      0
# 2                      5
# 3                     10
# 4                    7.5
# ..                   ...
# 157                  2.5
# 158                  7.5
# 159                    0
# 160                  7.5
# 161                  7.5
#
# [162 rows x 32 columns]

# %%
personal_2017.isna().sum()
# Out:
# hf_score                                0
# pf_ss_women_fgm                         0
# pf_ss_women_inheritance                 2
# pf_ss_women                             0
# pf_movement_domestic                    1
# pf_movement_foreign                     1
# pf_movement_women                       1
# pf_religion_estop                      26
# pf_religion_harassment                  2
# pf_religion_restrictions                2
# pf_association_association             26
# pf_association_assembly                26
# pf_association_political_establish    162
# pf_association_political_operate      162
# pf_association_political               26
# pf_association_prof_establish         162
# pf_association_prof_operate           162
# pf_association_prof                    26
# pf_association_sport_establish        162
# pf_association_sport_operate          162
# pf_association_sport                   26
# pf_expression_killed                    0
# pf_expression_jailed                    0
# pf_expression_influence                 0
# pf_expression_control                   0
# pf_expression_newspapers               28
# pf_expression_internet                 26
# pf_identity_legal                      59
# pf_identity_sex_male                    0
# pf_identity_sex_female                  0
# pf_identity_sex                         0
# pf_identity_divorce                     1
# dtype: int64

# %%
personal_2017.drop(columns=['pf_association_political_establish',
                           'pf_association_political_establish',
                           'pf_association_political_operate',
                           'pf_association_prof_establish',
                           'pf_association_prof_operate',
                           'pf_association_sport_establish',
                           'pf_association_sport_operate'], inplace=True)
# personal_2017.pf_association_prof_operate.drop(inplace=True)
# personal_2017.pf_association_prof_establish.drop(inplace=True)
# personal_2017.pf_association_prof_operate.drop(inplace=True)
# personal_2017.pf_association_sport_establish.drop(inplace=True)
# personal_2017.pf_association_sport_operate.drop(inplace=True)

# %%
personal_2017.head(2)
# Out:
#   hf_score pf_ss_women_fgm pf_ss_women_inheritance pf_ss_women  \
# 0     7.84              10                     7.5         8.8
# 1     4.99              10                       0           5
#
#   pf_movement_domestic pf_movement_foreign pf_movement_women  \
# 0                   10                  10                10
# 1                   10                   5               2.5
#
#   pf_religion_estop pf_religion_harassment pf_religion_restrictions  ...  \
# 0                10                    9.6                        8  ...
# 1                 5                    6.9                        3  ...
#
#   pf_expression_jailed pf_expression_influence pf_expression_control  \
# 0                   10                       5                   5.3
# 1                  9.5                     2.7                     4
#
#   pf_expression_newspapers pf_expression_internet pf_identity_legal  \
# 0                       10                     10                 0
# 1                      7.5                    7.5               NaN
#
#   pf_identity_sex_male pf_identity_sex_female pf_identity_sex  \
# 0                   10                     10              10
# 1                    0                      0               0
#
#   pf_identity_divorce
# 0                 7.5
# 1                   0
#
# [2 rows x 26 columns]

# %%
personal_2017.isna().sum()
# Out:
# hf_score                       0
# pf_ss_women_fgm                0
# pf_ss_women_inheritance        2
# pf_ss_women                    0
# pf_movement_domestic           1
# pf_movement_foreign            1
# pf_movement_women              1
# pf_religion_estop             26
# pf_religion_harassment         2
# pf_religion_restrictions       2
# pf_association_association    26
# pf_association_assembly       26
# pf_association_political      26
# pf_association_prof           26
# pf_association_sport          26
# pf_expression_killed           0
# pf_expression_jailed           0
# pf_expression_influence        0
# pf_expression_control          0
# pf_expression_newspapers      28
# pf_expression_internet        26
# pf_identity_legal             59
# pf_identity_sex_male           0
# pf_identity_sex_female         0
# pf_identity_sex                0
# pf_identity_divorce            1
# dtype: int64

# %%
personal_2017.dropna(inplace=True)
personal_2017.head()
# Out:
#   hf_score pf_ss_women_fgm pf_ss_women_inheritance pf_ss_women  \
# 0     7.84              10                     7.5         8.8
# 2      5.4              10                       5         7.5
# 3     6.86              10                      10          10
# 4     7.42              10                     7.5         8.8
# 5     8.62              10                      10          10
#
#   pf_movement_domestic pf_movement_foreign pf_movement_women  \
# 0                   10                  10                10
# 2                    5                   5                10
# 3                   10                  10                10
# 4                   10                   5                10
# 5                   10                  10                10
#
#   pf_religion_estop pf_religion_harassment pf_religion_restrictions  ...  \
# 0                10                    9.6                        8  ...
# 2                10                    8.9                      7.5  ...
# 3               7.5                      9                      6.9  ...
# 4                 5                    8.6                      5.1  ...
# 5                10                    8.3                      8.9  ...
#
#   pf_expression_jailed pf_expression_influence pf_expression_control  \
# 0                   10                       5                   5.3
# 2                   10                     2.7                   2.5
# 3                   10                     5.7                   5.5
# 4                   10                     3.3                   4.3
# 5                   10                       8                   7.8
#
#   pf_expression_newspapers pf_expression_internet pf_identity_legal  \
# 0                       10                     10                 0
# 2                        5                    7.5                10
# 3                       10                     10                10
# 4                      7.5                    7.5                 7
# 5                       10                     10                 7
#
#   pf_identity_sex_male pf_identity_sex_female pf_identity_sex  \
# 0                   10                     10              10
# 2                    0                      0               0
# 3                   10                     10              10
# 4                   10                     10              10
# 5                   10                     10              10
#
#   pf_identity_divorce
# 0                 7.5
# 2                   5
# 3                  10
# 4                 7.5
# 5                  10
#
# [5 rows x 26 columns]

# %%
personal_2017 = personal_2017.astype(float)

personal_2017
# Out:
#      hf_score  pf_ss_women_fgm  pf_ss_women_inheritance  pf_ss_women  \
# 0        7.84             10.0                      7.5          8.8
# 2        5.40             10.0                      5.0          7.5
# 3        6.86             10.0                     10.0         10.0
# 4        7.42             10.0                      7.5          8.8
# 5        8.62             10.0                     10.0         10.0
# ..        ...              ...                      ...          ...
# 154      8.47             10.0                      7.5          8.8
# 155      8.46             10.0                     10.0         10.0
# 156      7.74             10.0                     10.0         10.0
# 157      3.80             10.0                     10.0         10.0
# 158      6.29             10.0                      7.5          8.8
#
#      pf_movement_domestic  pf_movement_foreign  pf_movement_women  \
# 0                    10.0                 10.0               10.0
# 2                     5.0                  5.0               10.0
# 3                    10.0                 10.0               10.0
# 4                    10.0                  5.0               10.0
# 5                    10.0                 10.0               10.0
# ..                    ...                  ...                ...
# 154                  10.0                 10.0               10.0
# 155                  10.0                 10.0               10.0
# 156                  10.0                 10.0               10.0
# 157                   0.0                 10.0               10.0
# 158                   0.0                  5.0               10.0
#
#      pf_religion_estop  pf_religion_harassment  pf_religion_restrictions  ...  \
# 0                 10.0                     9.6                       8.0  ...
# 2                 10.0                     8.9                       7.5  ...
# 3                  7.5                     9.0                       6.9  ...
# 4                  5.0                     8.6                       5.1  ...
# 5                 10.0                     8.3                       8.9  ...
# ..                 ...                     ...                       ...  ...
# 154               10.0                     7.6                       5.2  ...
# 155               10.0                     7.9                       8.7  ...
# 156                7.5                     9.0                       8.9  ...
# 157                5.0                     9.0                       6.6  ...
# 158                2.5                     8.6                       6.6  ...
#
#      pf_expression_jailed  pf_expression_influence  pf_expression_control  \
# 0                    10.0                      5.0                    5.3
# 2                    10.0                      2.7                    2.5
# 3                    10.0                      5.7                    5.5
# 4                    10.0                      3.3                    4.3
# 5                    10.0                      8.0                    7.8
# ..                    ...                      ...                    ...
# 154                  10.0                      7.0                    7.8
# 155                  10.0                      8.0                    7.0
# 156                  10.0                      8.0                    7.5
# 157                   9.7                      1.3                    2.3
# 158                   9.0                      0.0                    1.8
#
#      pf_expression_newspapers  pf_expression_internet  pf_identity_legal  \
# 0                        10.0                    10.0                0.0
# 2                         5.0                     7.5               10.0
# 3                        10.0                    10.0               10.0
# 4                         7.5                     7.5                7.0
# 5                        10.0                    10.0                7.0
# ..                        ...                     ...                ...
# 154                      10.0                    10.0                7.0
# 155                      10.0                    10.0                7.0
# 156                      10.0                    10.0               10.0
# 157                       2.5                     5.0                0.0
# 158                       7.5                     5.0               10.0
#
#      pf_identity_sex_male  pf_identity_sex_female  pf_identity_sex  \
# 0                    10.0                    10.0             10.0
# 2                     0.0                     0.0              0.0
# 3                    10.0                    10.0             10.0
# 4                    10.0                    10.0             10.0
# 5                    10.0                    10.0             10.0
# ..                    ...                     ...              ...
# 154                  10.0                    10.0             10.0
# 155                  10.0                    10.0             10.0
# 156                  10.0                    10.0             10.0
# 157                  10.0                    10.0             10.0
# 158                  10.0                    10.0             10.0
#
#      pf_identity_divorce
# 0                    7.5
# 2                    5.0
# 3                   10.0
# 4                    7.5
# 5                   10.0
# ..                   ...
# 154                 10.0
# 155                 10.0
# 156                 10.0
# 157                  2.5
# 158                  7.5
#
# [91 rows x 26 columns]

# %%
personal_2017.drop('hf_score', axis=1, inplace=True)

# %%
personal_2017['total'] = personal_2017.mean(axis=1)

# %%
personal_2017
# Out:
#      pf_ss_women_fgm  pf_ss_women_inheritance  pf_ss_women  \
# 0               10.0                      7.5          8.8
# 2               10.0                      5.0          7.5
# 3               10.0                     10.0         10.0
# 4               10.0                      7.5          8.8
# 5               10.0                     10.0         10.0
# ..               ...                      ...          ...
# 154             10.0                      7.5          8.8
# 155             10.0                     10.0         10.0
# 156             10.0                     10.0         10.0
# 157             10.0                     10.0         10.0
# 158             10.0                      7.5          8.8
#
#      pf_movement_domestic  pf_movement_foreign  pf_movement_women  \
# 0                    10.0                 10.0               10.0
# 2                     5.0                  5.0               10.0
# 3                    10.0                 10.0               10.0
# 4                    10.0                  5.0               10.0
# 5                    10.0                 10.0               10.0
# ..                    ...                  ...                ...
# 154                  10.0                 10.0               10.0
# 155                  10.0                 10.0               10.0
# 156                  10.0                 10.0               10.0
# 157                   0.0                 10.0               10.0
# 158                   0.0                  5.0               10.0
#
#      pf_religion_estop  pf_religion_harassment  pf_religion_restrictions  \
# 0                 10.0                     9.6                       8.0
# 2                 10.0                     8.9                       7.5
# 3                  7.5                     9.0                       6.9
# 4                  5.0                     8.6                       5.1
# 5                 10.0                     8.3                       8.9
# ..                 ...                     ...                       ...
# 154               10.0                     7.6                       5.2
# 155               10.0                     7.9                       8.7
# 156                7.5                     9.0                       8.9
# 157                5.0                     9.0                       6.6
# 158                2.5                     8.6                       6.6
#
#      pf_association_association  ...  pf_expression_influence  \
# 0                          10.0  ...                      5.0
# 2                           2.5  ...                      2.7
# 3                           7.5  ...                      5.7
# 4                           7.5  ...                      3.3
# 5                          10.0  ...                      8.0
# ..                          ...  ...                      ...
# 154                        10.0  ...                      7.0
# 155                        10.0  ...                      8.0
# 156                         7.5  ...                      8.0
# 157                        10.0  ...                      1.3
# 158                         2.5  ...                      0.0
#
#      pf_expression_control  pf_expression_newspapers  pf_expression_internet  \
# 0                      5.3                      10.0                    10.0
# 2                      2.5                       5.0                     7.5
# 3                      5.5                      10.0                    10.0
# 4                      4.3                       7.5                     7.5
# 5                      7.8                      10.0                    10.0
# ..                     ...                       ...                     ...
# 154                    7.8                      10.0                    10.0
# 155                    7.0                      10.0                    10.0
# 156                    7.5                      10.0                    10.0
# 157                    2.3                       2.5                     5.0
# 158                    1.8                       7.5                     5.0
#
#      pf_identity_legal  pf_identity_sex_male  pf_identity_sex_female  \
# 0                  0.0                  10.0                    10.0
# 2                 10.0                   0.0                     0.0
# 3                 10.0                  10.0                    10.0
# 4                  7.0                  10.0                    10.0
# 5                  7.0                  10.0                    10.0
# ..                 ...                   ...                     ...
# 154                7.0                  10.0                    10.0
# 155                7.0                  10.0                    10.0
# 156               10.0                  10.0                    10.0
# 157                0.0                  10.0                    10.0
# 158               10.0                  10.0                    10.0
#
#      pf_identity_sex  pf_identity_divorce     total
# 0               10.0                  7.5  8.866479
# 2                0.0                  5.0  5.663609
# 3               10.0                 10.0  8.881006
# 4               10.0                  7.5  7.583757
# 5               10.0                 10.0  9.598550
# ..               ...                  ...       ...
# 154             10.0                 10.0  9.234867
# 155             10.0                 10.0  9.542396
# 156             10.0                 10.0  9.133935
# 157             10.0                  2.5  6.651775
# 158             10.0                  7.5  5.892589
#
# [91 rows x 26 columns]

# %%
for col in personal_2017:

    personal_2017[col] = (personal_2017[col] - personal_2017[col].mean())/personal_2017[col].std()  
    personal_2017[col]
personal_2017.head()
# Out:
#    hf_score  pf_ss_women_fgm  pf_ss_women_inheritance  pf_ss_women  \
# 0  0.480476         0.144806                -0.225377    -0.181192
# 2 -1.987939         0.144806                -1.117086    -1.081821
# 3 -0.510937         0.144806                 0.666332     0.650159
# 4  0.055585         0.144806                -0.225377    -0.181192
# 5  1.269559         0.144806                 0.666332     0.650159
#
#    pf_movement_domestic  pf_movement_foreign  pf_movement_women  \
# 0              0.418926             0.585764            0.29698
# 2             -1.169502            -1.133736            0.29698
# 3              0.418926             0.585764            0.29698
# 4              0.418926            -1.133736            0.29698
# 5              0.418926             0.585764            0.29698
#
#    pf_religion_estop  pf_religion_harassment  pf_religion_restrictions  ...  \
# 0           0.801857                1.358046                  0.837386  ...
# 2           0.801857                0.607764                  0.546316  ...
# 3          -0.098995                0.714947                  0.197032  ...
# 4          -0.999846                0.286214                 -0.850820  ...
# 5           0.801857               -0.035335                  1.361312  ...
#
#    pf_expression_jailed  pf_expression_influence  pf_expression_control  \
# 0              0.208983                -0.254143              -0.103995
# 2              0.208983                -1.123295              -1.292237
# 3              0.208983                 0.010382              -0.019120
# 4              0.208983                -0.896559              -0.528367
# 5              0.208983                 0.879533               0.956936
#
#    pf_expression_newspapers  pf_expression_internet  pf_identity_legal  \
# 0                  0.485522                0.625695          -1.857593
# 2                 -2.113447               -0.797761           0.941098
# 3                  0.485522                0.625695           0.941098
# 4                 -0.813963               -0.797761           0.101491
# 5                  0.485522                0.625695           0.101491
#
#    pf_identity_sex_male  pf_identity_sex_female  pf_identity_sex  \
# 0              0.419653                0.258563         0.395893
# 2             -2.409119               -4.019483        -3.396341
# 3              0.419653                0.258563         0.395893
# 4              0.419653                0.258563         0.395893
# 5              0.419653                0.258563         0.395893
#
#    pf_identity_divorce
# 0            -0.080422
# 2            -0.893583
# 3             0.732738
# 4            -0.080422
# 5             0.732738
#
# [5 rows x 26 columns]

# %% [markdown]
# # Running a Regression Model test using Stats Model

# %%
import statsmodels.api as sm

X = personal_2017.drop(columns='hf_score').values

y = personal_2017.hf_score

x_col = list(personal_2017.drop(columns='hf_score').columns)
# Fitting the actual model

X = sm.add_constant(X)
model = sm.OLS(y, X, hasconst=True )

result = model.fit()

labels = ['intercept'] + x_col

result.summary(xname=labels)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               hf_score   R-squared:                       0.878
# Model:                            OLS   Adj. R-squared:                  0.834
# Method:                 Least Squares   F-statistic:                     19.88
# Date:                Tue, 03 Mar 2020   Prob (F-statistic):           1.20e-21
# Time:                        16:52:15   Log-Likelihood:                -32.718
# No. Observations:                  91   AIC:                             115.4
# Df Residuals:                      66   BIC:                             178.2
# Df Model:                          24
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# intercept                  -7.869e-15      0.043  -1.84e-13      1.000      -0.085       0.085
# pf_ss_women_fgm               -0.2446      0.330     -0.741      0.461      -0.904       0.415
# pf_ss_women_inheritance       -1.8710      3.498     -0.535      0.595      -8.854       5.113
# pf_ss_women                    2.1499      3.627      0.593      0.555      -5.091       9.390
# pf_movement_domestic           0.1687      0.060      2.831      0.006       0.050       0.288
# pf_movement_foreign            0.0116      0.083      0.139      0.890      -0.155       0.178
# pf_movement_women              0.0905      0.054      1.680      0.098      -0.017       0.198
# pf_religion_estop             -0.1482      0.098     -1.519      0.133      -0.343       0.047
# pf_religion_harassment        -0.0611      0.070     -0.872      0.386      -0.201       0.079
# pf_religion_restrictions      -0.0135      0.072     -0.187      0.853      -0.158       0.131
# pf_association_association    -0.1624      0.121     -1.340      0.185      -0.404       0.080
# pf_association_assembly       -0.1815      0.103     -1.770      0.081      -0.386       0.023
# pf_association_political       0.2580      0.107      2.412      0.019       0.044       0.472
# pf_association_prof            0.0830      0.091      0.908      0.367      -0.099       0.265
# pf_association_sport           0.0446      0.110      0.407      0.686      -0.174       0.263
# pf_expression_killed          -0.0309      0.050     -0.612      0.543      -0.132       0.070
# pf_expression_jailed          -0.0492      0.057     -0.862      0.392      -0.163       0.065
# pf_expression_influence       -0.1567      0.151     -1.036      0.304      -0.459       0.145
# pf_expression_control          0.7070      0.147      4.822      0.000       0.414       1.000
# pf_expression_newspapers       0.2437      0.083      2.945      0.004       0.079       0.409
# pf_expression_internet         0.0526      0.087      0.605      0.547      -0.121       0.226
# pf_identity_legal              0.0511      0.058      0.885      0.379      -0.064       0.166
# pf_identity_sex_male           0.0727      0.069      1.054      0.296      -0.065       0.210
# pf_identity_sex_female        -0.0921      0.073     -1.262      0.212      -0.238       0.054
# pf_identity_sex                0.0079      0.032      0.247      0.806      -0.056       0.072
# pf_identity_divorce            0.0820      0.068      1.204      0.233      -0.054       0.218
# ==============================================================================
# Omnibus:                        3.474   Durbin-Watson:                   1.765
# Prob(Omnibus):                  0.176   Jarque-Bera (JB):                2.762
# Skew:                           0.376   Prob(JB):                        0.251
# Kurtosis:                       3.404   Cond. No.                     2.25e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.73e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
subset_personal = personal_2017[['hf_score','pf_movement_domestic', 'pf_movement_women','pf_expression_newspapers', 'pf_expression_control', 
                    'pf_association_political', 'pf_association_assembly', 'pf_ss_women','pf_expression_internet']]
subset_personal
# Out:
#      hf_score  pf_movement_domestic  pf_movement_women  \
# 0    0.480476              0.418926            0.29698
# 2   -1.987939             -1.169502            0.29698
# 3   -0.510937              0.418926            0.29698
# 4    0.055585              0.418926            0.29698
# 5    1.269559              0.418926            0.29698
# ..        ...                   ...                ...
# 154  1.117813              0.418926            0.29698
# 155  1.107696              0.418926            0.29698
# 156  0.379311              0.418926            0.29698
# 157 -3.606572             -2.757931            0.29698
# 158 -1.087574             -2.757931            0.29698
#
#      pf_expression_newspapers  pf_expression_control  \
# 0                    0.485522              -0.103995
# 2                   -2.113447              -1.292237
# 3                    0.485522              -0.019120
# 4                   -0.813963              -0.528367
# 5                    0.485522               0.956936
# ..                        ...                    ...
# 154                  0.485522               0.956936
# 155                  0.485522               0.617438
# 156                  0.485522               0.829624
# 157                 -3.412932              -1.377111
# 158                 -0.813963              -1.589297
#
#      pf_association_political  pf_association_assembly  pf_ss_women  \
# 0                    0.868243                 0.734364    -0.181192
# 2                   -1.550434                -2.213892    -1.081821
# 3                   -0.744208                 0.734364     0.650159
# 4                   -0.744208                -0.248388    -0.181192
# 5                    0.868243                 0.734364     0.650159
# ..                        ...                      ...          ...
# 154                  0.868243                 0.734364    -0.181192
# 155                  0.868243                 0.734364     0.650159
# 156                 -0.744208                 0.734364     0.650159
# 157                 -1.550434                 0.734364     0.650159
# 158                 -2.356660                -2.213892    -0.181192
#
#      pf_expression_internet
# 0                  0.625695
# 2                 -0.797761
# 3                  0.625695
# 4                 -0.797761
# 5                  0.625695
# ..                      ...
# 154                0.625695
# 155                0.625695
# 156                0.625695
# 157               -2.221216
# 158               -2.221216
#
# [91 rows x 9 columns]

# %%
import statsmodels.api as sm

X = subset_personal.drop(columns='hf_score').values

y = subset_personal.hf_score

x_col = list(subset_personal.drop(columns='hf_score').columns)
# Fitting the actual model

X = sm.add_constant(X)
model = sm.OLS(y, X, hasconst=True )

result = model.fit()

labels = ['intercept'] + x_col

result.summary(xname=labels)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               hf_score   R-squared:                       0.846
# Model:                            OLS   Adj. R-squared:                  0.831
# Method:                 Least Squares   F-statistic:                     56.28
# Date:                Tue, 03 Mar 2020   Prob (F-statistic):           4.04e-30
# Time:                        16:53:22   Log-Likelihood:                -43.520
# No. Observations:                  91   AIC:                             105.0
# Df Residuals:                      82   BIC:                             127.6
# Df Model:                           8
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# intercept                -1.804e-16      0.043  -4.19e-15      1.000      -0.086       0.086
# pf_movement_domestic         0.1928      0.051      3.779      0.000       0.091       0.294
# pf_movement_women            0.0859      0.048      1.809      0.074      -0.009       0.180
# pf_expression_newspapers     0.1980      0.065      3.061      0.003       0.069       0.327
# pf_expression_control        0.5514      0.074      7.501      0.000       0.405       0.698
# pf_association_political     0.2194      0.078      2.804      0.006       0.064       0.375
# pf_association_assembly     -0.2701      0.071     -3.786      0.000      -0.412      -0.128
# pf_ss_women                  0.2192      0.053      4.118      0.000       0.113       0.325
# pf_expression_internet       0.0184      0.070      0.263      0.793      -0.120       0.157
# ==============================================================================
# Omnibus:                        2.986   Durbin-Watson:                   1.712
# Prob(Omnibus):                  0.225   Jarque-Bera (JB):                2.343
# Skew:                          -0.275   Prob(JB):                        0.310
# Kurtosis:                       3.562   Cond. No.                         4.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Getting political columns from the main dataframe
political = df[['year',
'hf_score',
"pf_rol_procedural",
"pf_rol_civil",
"pf_rol_criminal",
"pf_ss_homicide",
"pf_ss_disappearances_disap",
"pf_ss_disappearances_violent",
"pf_ss_disappearances_organized",
"pf_ss_disappearances_fatalities",
"pf_ss_disappearances_injuries",
"pf_ss_disappearances",
"ef_legal_judicial",
"ef_legal_courts",
"ef_legal_protection",
"ef_legal_military",
"ef_legal_integrity",
"ef_legal_enforcement",
"ef_legal_restrictions",
"ef_legal_police",
"ef_legal_crime",
"ef_legal_gender",]]

"""
This is the main dataframe
for political categories
"""
# Out:
# '\nThis is the main dataframe\nfor political categories\n'

# %%
political_2017 = year(political, 2017) # Retrieving political data from 2017

# %%
political_2017 = political_2017.drop(columns=["year"])

# %%
political_2010.head(2)
# Out:
#       year hf_score pf_rol_procedural pf_rol_civil pf_rol_criminal  \
# 1134  2010     7.71               5.7          5.1             4.1
# 1135  2010     5.26                 -            -               -
#
#      pf_ss_homicide pf_ss_disappearances_disap pf_ss_disappearances_violent  \
# 1134            8.3                         10                           10
# 1135            9.7                         10                          7.8
#
#      pf_ss_disappearances_organized pf_ss_disappearances_fatalities  ...  \
# 1134                             10                              10  ...
# 1135                              5                               9  ...
#
#      ef_legal_judicial ef_legal_courts ef_legal_protection ef_legal_military  \
# 1134               3.3             4.5                   4               8.3
# 1135               2.5             3.3                 3.5                 5
#
#      ef_legal_integrity ef_legal_enforcement ef_legal_restrictions  \
# 1134                4.2                  5.4                   5.5
# 1135                  5                  4.4                   6.8
#
#      ef_legal_police ef_legal_crime ef_legal_gender
# 1134             5.9            7.2               1
# 1135             4.6            4.9             0.7
#
# [2 rows x 22 columns]

# %%
def replace_with_na(df):
    for strings in df.values:
        df.replace('-', np.NaN, regex=True, inplace=True)

# %%
replace_with_na(political_2017)

# %%
political_2017.isna().sum()
# Out:
# hf_score                            0
# pf_rol_procedural                  57
# pf_rol_civil                       57
# pf_rol_criminal                    57
# pf_ss_homicide                      0
# pf_ss_disappearances_disap          1
# pf_ss_disappearances_violent        0
# pf_ss_disappearances_organized     11
# pf_ss_disappearances_fatalities     0
# pf_ss_disappearances_injuries       0
# pf_ss_disappearances                0
# ef_legal_judicial                   6
# ef_legal_courts                     0
# ef_legal_protection                 5
# ef_legal_military                   0
# ef_legal_integrity                 25
# ef_legal_enforcement                1
# ef_legal_restrictions               2
# ef_legal_police                    14
# ef_legal_crime                     10
# ef_legal_gender                     0
# dtype: int64

# %%
political_2017.dropna(inplace=True)
political_2017.isna().sum()
# Out:
# hf_score                           0
# pf_rol_procedural                  0
# pf_rol_civil                       0
# pf_rol_criminal                    0
# pf_ss_homicide                     0
# pf_ss_disappearances_disap         0
# pf_ss_disappearances_violent       0
# pf_ss_disappearances_organized     0
# pf_ss_disappearances_fatalities    0
# pf_ss_disappearances_injuries      0
# pf_ss_disappearances               0
# ef_legal_judicial                  0
# ef_legal_courts                    0
# ef_legal_protection                0
# ef_legal_military                  0
# ef_legal_integrity                 0
# ef_legal_enforcement               0
# ef_legal_restrictions              0
# ef_legal_police                    0
# ef_legal_crime                     0
# ef_legal_gender                    0
# dtype: int64

# %%
political_2017 = political_2017.astype(float)

political_2017.head(2)
# Out:
#    hf_score  pf_rol_procedural  pf_rol_civil  pf_rol_criminal  pf_ss_homicide  \
# 0      7.84                6.7           4.5              4.7             9.1
# 3      6.86                7.1           5.8              4.3             8.0
#
#    pf_ss_disappearances_disap  pf_ss_disappearances_violent  \
# 0                        10.0                          10.0
# 3                         5.0                          10.0
#
#    pf_ss_disappearances_organized  pf_ss_disappearances_fatalities  \
# 0                            10.0                             10.0
# 3                             7.5                             10.0
#
#    pf_ss_disappearances_injuries  ...  ef_legal_judicial  ef_legal_courts  \
# 0                           10.0  ...                2.5              3.1
# 3                           10.0  ...                3.6              3.0
#
#    ef_legal_protection  ef_legal_military  ef_legal_integrity  \
# 0                  4.6                8.3                 4.2
# 3                  4.4                7.5                 3.3
#
#    ef_legal_enforcement  ef_legal_restrictions  ef_legal_police  \
# 0                   4.4                    6.6              6.8
# 3                   3.6                    6.9              3.7
#
#    ef_legal_crime  ef_legal_gender
# 0             6.2              1.0
# 3             4.1              0.8
#
# [2 rows x 21 columns]

# %%
political_2017.drop('hf_score', axis=1, inplace=True)

# %%
political_2017['total'] = political_2017.mean(axis=1)

political_2017
# Out:
#      pf_rol_procedural  pf_rol_civil  pf_rol_criminal  pf_ss_homicide  \
# 0                  6.7           4.5              4.7             9.1
# 3                  7.1           5.8              4.3             8.0
# 5                  8.4           7.5              7.4             9.7
# 6                  9.0           7.9              7.7             9.7
# 10                 1.5           3.7              3.4             9.1
# ..                 ...           ...              ...             ...
# 156                6.2           7.4              5.4             6.7
# 157                1.5           3.3              1.4             0.0
# 158                5.4           4.4              4.9             9.4
# 160                2.1           4.9              4.2             7.9
# 161                1.5           4.3              3.8             7.3
#
#      pf_ss_disappearances_disap  pf_ss_disappearances_violent  \
# 0                          10.0                          10.0
# 3                           5.0                          10.0
# 5                          10.0                          10.0
# 6                          10.0                          10.0
# 10                          0.0                           9.9
# ..                          ...                           ...
# 156                        10.0                          10.0
# 157                        10.0                          10.0
# 158                        10.0                          10.0
# 160                        10.0                          10.0
# 161                        10.0                          10.0
#
#      pf_ss_disappearances_organized  pf_ss_disappearances_fatalities  \
# 0                              10.0                             10.0
# 3                               7.5                             10.0
# 5                              10.0                              9.9
# 6                              10.0                              9.9
# 10                              5.0                              9.9
# ..                              ...                              ...
# 156                            10.0                             10.0
# 157                             5.0                              9.9
# 158                            10.0                             10.0
# 160                             7.5                             10.0
# 161                             5.0                             10.0
#
#      pf_ss_disappearances_injuries  pf_ss_disappearances  ...  \
# 0                             10.0                  10.0  ...
# 3                             10.0                   8.5  ...
# 5                              9.8                  10.0  ...
# 6                             10.0                  10.0  ...
# 10                             9.9                   7.0  ...
# ..                             ...                   ...  ...
# 156                           10.0                  10.0  ...
# 157                            9.8                   8.9  ...
# 158                           10.0                  10.0  ...
# 160                           10.0                   9.5  ...
# 161                           10.0                   9.0  ...
#
#      ef_legal_courts  ef_legal_protection  ef_legal_military  \
# 0                3.1                  4.6                8.3
# 3                3.0                  4.4                7.5
# 5                5.7                  8.2               10.0
# 6                5.6                  8.2               10.0
# 10               3.5                  5.1                4.2
# ..               ...                  ...                ...
# 156              4.4                  6.5                5.8
# 157              0.6                  1.2                0.8
# 158              4.0                  4.9                5.0
# 160              3.7                  5.5                8.3
# 161              3.4                  2.6                3.3
#
#      ef_legal_integrity  ef_legal_enforcement  ef_legal_restrictions  \
# 0                   4.2                   4.4                    6.6
# 3                   3.3                   3.6                    6.9
# 5                   9.2                   6.0                    8.2
# 6                  10.0                   6.2                    8.1
# 10                  3.3                   0.9                    2.7
# ..                  ...                   ...                    ...
# 156                 4.2                   3.6                    6.5
# 157                 1.7                   2.4                    8.1
# 158                 6.7                   5.7                    8.8
# 160                 6.7                   3.5                    6.0
# 161                 5.0                   2.4                    6.8
#
#      ef_legal_police  ef_legal_crime  ef_legal_gender  total
# 0                6.8             6.2              1.0  6.635
# 3                3.7             4.1              0.8  5.855
# 5                8.6             6.8              1.0  8.255
# 6                8.5             7.2              1.0  8.335
# 10               3.9             4.7              0.8  4.615
# ..               ...             ...              ...    ...
# 156              5.3             4.4              1.0  6.745
# 157              1.3             1.6              1.0  3.935
# 158              5.5             6.1              0.8  6.790
# 160              4.5             5.7              1.0  6.235
# 161              4.0             5.7              1.0  5.420
#
# [92 rows x 21 columns]

# %%
for col in political_2017:

    political_2017[col] = (political_2017[col] - political_2017[col].mean())/political_2017[col].std()  
    political_2017[col]
political_2017.head()
# Out:
#     hf_score  pf_rol_procedural  pf_rol_civil  pf_rol_criminal  \
# 0   0.728481           0.663009     -0.794304        -0.129515
# 3  -0.241106           0.833630      0.136144        -0.370230
# 5   1.500193           1.388146      1.352884         1.495310
# 6   1.361680           1.644077      1.639176         1.675846
# 10 -1.319524          -1.555058     -1.366888        -0.911838
#
#     pf_ss_homicide  pf_ss_disappearances_disap  pf_ss_disappearances_violent  \
# 0         0.520862                    0.532742                      0.299358
# 3         0.151477                   -1.157336                      0.299358
# 5         0.722345                    0.532742                      0.299358
# 6         0.722345                    0.532742                      0.299358
# 10        0.520862                   -2.847414                      0.199209
#
#     pf_ss_disappearances_organized  pf_ss_disappearances_fatalities  \
# 0                         1.040516                         0.356859
# 3                         0.083241                         0.356859
# 5                         1.040516                         0.195130
# 6                         1.040516                         0.195130
# 10                       -0.874033                         0.195130
#
#     pf_ss_disappearances_injuries  ...  ef_legal_judicial  ef_legal_courts  \
# 0                        0.438467  ...          -1.161761        -0.732588
# 3                        0.438467  ...          -0.646102        -0.797896
# 5                       -0.030591  ...           1.744680         0.965426
# 6                        0.438467  ...           1.275899         0.900117
# 10                       0.203938  ...          -0.552346        -0.471355
#
#     ef_legal_protection  ef_legal_military  ef_legal_integrity  \
# 0             -0.723754           0.620185           -0.843856
# 3             -0.852795           0.304517           -1.269123
# 5              1.598991           1.290980            1.518736
# 6              1.598991           1.290980            1.896750
# 10            -0.401150          -0.997615           -1.269123
#
#     ef_legal_enforcement  ef_legal_restrictions  ef_legal_police  \
# 0              -0.034341              -0.769697         0.578160
# 3              -0.622130              -0.555115        -1.077374
# 5               1.141238               0.374741         1.539437
# 6               1.288185               0.303214         1.486033
# 10             -2.605920              -3.559266        -0.970565
#
#     ef_legal_crime  ef_legal_gender
# 0         0.420688         0.710077
# 3        -0.855244        -0.757947
# 5         0.785240         0.710077
# 6         1.028274         0.710077
# 10       -0.490692        -0.757947
#
# [5 rows x 21 columns]

# %%
#Model for political variables

import statsmodels.api as sm

X = political_2017.drop(columns='hf_score').values

y = political_2017.hf_score

x_col = list(political_2017.drop(columns='hf_score').columns)
# Fitting the actual model

X = sm.add_constant(X)
model = sm.OLS(y, X, hasconst=True )

result = model.fit()

labels = ['intercept'] + x_col

result.summary(xname=labels)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               hf_score   R-squared:                       0.888
# Model:                            OLS   Adj. R-squared:                  0.856
# Method:                 Least Squares   F-statistic:                     28.12
# Date:                Tue, 03 Mar 2020   Prob (F-statistic):           5.08e-26
# Time:                        16:54:06   Log-Likelihood:                -29.365
# No. Observations:                  92   AIC:                             100.7
# Df Residuals:                      71   BIC:                             153.7
# Df Model:                          20
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# intercept                        6.939e-16      0.040   1.76e-14      1.000      -0.079       0.079
# pf_rol_procedural                   0.4857      0.102      4.766      0.000       0.283       0.689
# pf_rol_civil                        0.1763      0.130      1.356      0.179      -0.083       0.436
# pf_rol_criminal                    -0.1507      0.171     -0.880      0.382      -0.492       0.191
# pf_ss_homicide                      0.1378      0.075      1.831      0.071      -0.012       0.288
# pf_ss_disappearances_disap         -0.5632      1.493     -0.377      0.707      -3.539       2.413
# pf_ss_disappearances_violent       -0.2930      0.502     -0.584      0.561      -1.294       0.708
# pf_ss_disappearances_organized     -0.4049      1.317     -0.308      0.759      -3.030       2.221
# pf_ss_disappearances_fatalities    -0.0613      0.310     -0.198      0.844      -0.679       0.556
# pf_ss_disappearances_injuries      -0.1882      0.255     -0.739      0.462      -0.696       0.319
# pf_ss_disappearances                1.2840      3.114      0.412      0.681      -4.925       7.493
# ef_legal_judicial                  -0.3048      0.127     -2.392      0.019      -0.559      -0.051
# ef_legal_courts                     0.0408      0.106      0.386      0.701      -0.170       0.251
# ef_legal_protection                 0.3442      0.141      2.444      0.017       0.063       0.625
# ef_legal_military                   0.1709      0.075      2.266      0.027       0.021       0.321
# ef_legal_integrity                 -0.0362      0.088     -0.409      0.684      -0.212       0.140
# ef_legal_enforcement                0.0107      0.057      0.189      0.850      -0.102       0.124
# ef_legal_restrictions               0.0194      0.053      0.364      0.717      -0.087       0.126
# ef_legal_police                     0.0343      0.125      0.275      0.784      -0.214       0.283
# ef_legal_crime                     -0.0766      0.107     -0.712      0.479      -0.291       0.138
# ef_legal_gender                     0.1842      0.061      3.013      0.004       0.062       0.306
# ==============================================================================
# Omnibus:                       25.871   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               56.497
# Skew:                          -1.014   Prob(JB):                     5.39e-13
# Kurtosis:                       6.260   Cond. No.                         289.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
subset_civil = political_2017[['hf_score',
'ef_legal_gender',
'ef_legal_military',
'ef_legal_protection',
'ef_legal_judicial',
'pf_rol_procedural']]

# %%
X = subset_civil.drop(columns='hf_score').values

y = subset_civil.hf_score

x_col = list(subset_civil.drop(columns='hf_score').columns)
# Fitting the actual model

X = sm.add_constant(X)
model = sm.OLS(y, X, hasconst=True )

result = model.fit()

labels = ['intercept'] + x_col

result.summary(xname=labels)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               hf_score   R-squared:                       0.861
# Model:                            OLS   Adj. R-squared:                  0.853
# Method:                 Least Squares   F-statistic:                     106.9
# Date:                Tue, 03 Mar 2020   Prob (F-statistic):           2.24e-35
# Time:                        16:36:36   Log-Likelihood:                -39.146
# No. Observations:                  92   AIC:                             90.29
# Df Residuals:                      86   BIC:                             105.4
# Df Model:                           5
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# intercept            6.939e-16      0.040   1.74e-14      1.000      -0.079       0.079
# ef_legal_gender         0.2079      0.048      4.307      0.000       0.112       0.304
# ef_legal_military       0.1586      0.064      2.485      0.015       0.032       0.286
# ef_legal_protection     0.4869      0.104      4.684      0.000       0.280       0.694
# ef_legal_judicial      -0.3450      0.102     -3.391      0.001      -0.547      -0.143
# pf_rol_procedural       0.5558      0.075      7.389      0.000       0.406       0.705
# ==============================================================================
# Omnibus:                       12.052   Durbin-Watson:                   2.059
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               20.008
# Skew:                          -0.512   Prob(JB):                     4.52e-05
# Kurtosis:                       5.042   Cond. No.                         6.26
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Grouping by Economic

# %%
# Getting economic columns from the main dataframe
economic = df[["year",'hf_score',
"ef_government_consumption",
"ef_government_transfers",
"ef_government_enterprises",
"ef_government_tax_income",
"ef_government_tax_payroll",
'ef_government_tax',
"ef_government_soa",
"ef_money_growth",
"ef_money_inflation",
"ef_money_currency",             
"ef_trade_tariffs_revenue",
"ef_trade_tariffs",
"ef_trade_regulatory_nontariff",
"ef_trade_regulatory_compliance",
"ef_trade_black",
"ef_trade_movement_foreign",
"ef_trade_movement_capital",
"ef_trade_movement_visit",
"ef_trade_movement",
"ef_regulation_credit_ownership"]]

"""
This is the main dataframe
for economic categories
"""
# Out:
# '\nThis is the main dataframe\nfor economic categories\n'

# %%
economic_2017 = year(economic, 2017)  # Retrieving economic data from 2017

# %%
# Dropping the year column

economic_2017 = economic_2017.drop(columns=["year"])

# %%
economic_2017.reset_index()
# Out:
#      index hf_score ef_government_consumption ef_government_transfers  \
# 0        0     7.84                       8.1                     7.3
# 1        1     4.99                       2.7                     7.8
# 2        2      5.4                       6.3                     8.9
# 3        3     6.86                       5.4                     6.3
# 4        4     7.42                       7.2                     7.3
# ..     ...      ...                       ...                     ...
# 157    157      3.8                       8.6                     5.8
# 158    158     6.29                       9.2                       -
# 159    159      4.3                        10                       9
# 160    160     6.49                       6.1                      10
# 161    161     5.65                       5.5                     9.3
#
#     ef_government_enterprises ef_government_tax_income  \
# 0                           8                        9
# 1                           0                        7
# 2                           6                       10
# 3                           6                        7
# 4                           8                        5
# ..                        ...                      ...
# 157                         0                        7
# 158                         6                        7
# 159                         4                       10
# 160                         4                        5
# 161                         6                        4
#
#     ef_government_tax_payroll ef_government_tax ef_government_soa  \
# 0                           7                 8               6.2
# 1                           2               4.5               2.9
# 2                           9               9.5               3.1
# 3                           1                 4               6.9
# 4                           5                 5               9.5
# ..                        ...               ...               ...
# 157                         6               6.5                 2
# 158                         5                 6               5.6
# 159                         8                 9               3.5
# 160                         4               4.5               8.5
# 161                         4                 4               2.7
#
#     ef_money_growth  ... ef_trade_tariffs_revenue ef_trade_tariffs  \
# 0               9.3  ...                      9.6                9
# 1                 7  ...                      8.5              6.9
# 2               9.4  ...                      9.2              7.1
# 3                 5  ...                      6.7              6.6
# 4               8.6  ...                        9              8.6
# ..              ...  ...                      ...              ...
# 157             2.8  ...                      8.4              7.3
# 158             8.3  ...                      9.1              7.6
# 159             9.9  ...                      8.9              8.4
# 160             7.9  ...                        9              5.8
# 161             9.4  ...                      6.2              4.8
#
#     ef_trade_regulatory_nontariff ef_trade_regulatory_compliance  \
# 0                               6                            9.4
# 1                             4.8                            0.5
# 2                             4.9                            2.5
# 3                             4.6                            5.2
# 4                             5.7                              9
# ..                            ...                            ...
# 157                           4.1                              0
# 158                           4.8                            5.7
# 159                             4                             10
# 160                           5.3                            2.4
# 161                           4.8                            1.3
#
#     ef_trade_black ef_trade_movement_foreign ef_trade_movement_capital  \
# 0               10                       6.3                       5.4
# 1                0                       3.7                         0
# 2                0                       2.9                       3.1
# 3               10                       5.4                       0.8
# 4               10                       5.1                       5.4
# ..             ...                       ...                       ...
# 157              0                       3.1                         0
# 158             10                       5.2                       0.8
# 159            4.8                       2.6                       6.9
# 160             10                       6.9                       9.2
# 161              3                       3.5                         0
#
#     ef_trade_movement_visit ef_trade_movement ef_regulation_credit_ownership
# 0                       8.3               6.7                             10
# 1                       1.1               1.6                              0
# 2                       0.1                 2                              5
# 3                         8               4.7                              5
# 4                        10               6.8                             10
# ..                      ...               ...                            ...
# 157                     7.2               3.4                              5
# 158                     0.8               2.2                              -
# 159                       1               3.5                              -
# 160                      10               8.7                              5
# 161                     8.9               4.1                              8
#
# [162 rows x 22 columns]

# %%
#Replacing '-' values in the data set to Null values 

def replace_with_na(df):
    for strings in df.values:
        df.replace('-', np.NaN, regex=True, inplace=True)
        
        
replace_with_na(economic_2017)
economic_2017.values
# Out:
# array([['7.84', '8.1', '7.3', ..., '8.3', '6.7', '10'],
#        ['4.99', '2.7', '7.8', ..., '1.1', '1.6', '0'],
#        ['5.4', '6.3', '8.9', ..., '0.1', '2', '5'],
#        ...,
#        ['4.3', '10', '9', ..., '1', '3.5', nan],
#        ['6.49', '6.1', '10', ..., '10', '8.7', '5'],
#        ['5.65', '5.5', '9.3', ..., '8.9', '4.1', '8']], dtype=object)

# %%
economic_2017.isna().sum()
# Out:
# hf_score                           0
# ef_government_consumption          0
# ef_government_transfers            9
# ef_government_enterprises          0
# ef_government_tax_income           0
# ef_government_tax_payroll          4
# ef_government_tax                  0
# ef_government_soa                  4
# ef_money_growth                    0
# ef_money_inflation                 0
# ef_money_currency                  0
# ef_trade_tariffs_revenue          11
# ef_trade_tariffs                   1
# ef_trade_regulatory_nontariff      3
# ef_trade_regulatory_compliance     2
# ef_trade_black                     0
# ef_trade_movement_foreign         10
# ef_trade_movement_capital          1
# ef_trade_movement_visit            1
# ef_trade_movement                  0
# ef_regulation_credit_ownership    11
# dtype: int64

# %%
economic_2017.dropna(inplace=True)
economic_2017.isna().sum()
# Out:
# hf_score                          0
# ef_government_consumption         0
# ef_government_transfers           0
# ef_government_enterprises         0
# ef_government_tax_income          0
# ef_government_tax_payroll         0
# ef_government_tax                 0
# ef_government_soa                 0
# ef_money_growth                   0
# ef_money_inflation                0
# ef_money_currency                 0
# ef_trade_tariffs_revenue          0
# ef_trade_tariffs                  0
# ef_trade_regulatory_nontariff     0
# ef_trade_regulatory_compliance    0
# ef_trade_black                    0
# ef_trade_movement_foreign         0
# ef_trade_movement_capital         0
# ef_trade_movement_visit           0
# ef_trade_movement                 0
# ef_regulation_credit_ownership    0
# dtype: int64

# %%
economic = economic_2017.astype(float)

economic
# Out:
#      hf_score  ef_government_consumption  ef_government_transfers  \
# 0        7.84                        8.1                      7.3
# 1        4.99                        2.7                      7.8
# 2        5.40                        6.3                      8.9
# 3        6.86                        5.4                      6.3
# 4        7.42                        7.2                      7.3
# ..        ...                        ...                      ...
# 155      8.46                        6.8                      6.0
# 156      7.74                        6.6                      5.9
# 157      3.80                        8.6                      5.8
# 160      6.49                        6.1                     10.0
# 161      5.65                        5.5                      9.3
#
#      ef_government_enterprises  ef_government_tax_income  \
# 0                          8.0                       9.0
# 1                          0.0                       7.0
# 2                          6.0                      10.0
# 3                          6.0                       7.0
# 4                          8.0                       5.0
# ..                         ...                       ...
# 155                        8.0                       5.0
# 156                        7.0                       7.0
# 157                        0.0                       7.0
# 160                        4.0                       5.0
# 161                        6.0                       4.0
#
#      ef_government_tax_payroll  ef_government_tax  ef_government_soa  \
# 0                          7.0                8.0                6.2
# 1                          2.0                4.5                2.9
# 2                          9.0                9.5                3.1
# 3                          1.0                4.0                6.9
# 4                          5.0                5.0                9.5
# ..                         ...                ...                ...
# 155                        5.0                5.0               10.0
# 156                        6.0                6.5                5.6
# 157                        6.0                6.5                2.0
# 160                        4.0                4.5                8.5
# 161                        4.0                4.0                2.7
#
#      ef_money_growth  ef_money_inflation  ...  ef_trade_tariffs_revenue  \
# 0                9.3                 9.6  ...                       9.6
# 1                7.0                 8.9  ...                       8.5
# 2                9.4                 3.7  ...                       9.2
# 3                5.0                 4.9  ...                       6.7
# 4                8.6                 9.8  ...                       9.0
# ..               ...                 ...  ...                       ...
# 155              9.7                 9.6  ...                       9.5
# 156              8.2                 8.8  ...                       8.4
# 157              2.8                 0.0  ...                       8.4
# 160              7.9                 8.7  ...                       9.0
# 161              9.4                 9.8  ...                       6.2
#
#      ef_trade_tariffs  ef_trade_regulatory_nontariff  \
# 0                 9.0                            6.0
# 1                 6.9                            4.8
# 2                 7.1                            4.9
# 3                 6.6                            4.6
# 4                 8.6                            5.7
# ..                ...                            ...
# 155               8.4                            7.0
# 156               7.7                            5.7
# 157               7.3                            4.1
# 160               5.8                            5.3
# 161               4.8                            4.8
#
#      ef_trade_regulatory_compliance  ef_trade_black  \
# 0                               9.4            10.0
# 1                               0.5             0.0
# 2                               2.5             0.0
# 3                               5.2            10.0
# 4                               9.0            10.0
# ..                              ...             ...
# 155                             9.8            10.0
# 156                             6.2            10.0
# 157                             0.0             0.0
# 160                             2.4            10.0
# 161                             1.3             3.0
#
#      ef_trade_movement_foreign  ef_trade_movement_capital  \
# 0                          6.3                        5.4
# 1                          3.7                        0.0
# 2                          2.9                        3.1
# 3                          5.4                        0.8
# 4                          5.1                        5.4
# ..                         ...                        ...
# 155                        7.2                        3.8
# 156                        7.0                        8.5
# 157                        3.1                        0.0
# 160                        6.9                        9.2
# 161                        3.5                        0.0
#
#      ef_trade_movement_visit  ef_trade_movement  \
# 0                        8.3                6.7
# 1                        1.1                1.6
# 2                        0.1                2.0
# 3                        8.0                4.7
# 4                       10.0                6.8
# ..                       ...                ...
# 155                      0.6                3.9
# 156                      7.7                7.7
# 157                      7.2                3.4
# 160                     10.0                8.7
# 161                      8.9                4.1
#
#      ef_regulation_credit_ownership
# 0                              10.0
# 1                               0.0
# 2                               5.0
# 3                               5.0
# 4                              10.0
# ..                              ...
# 155                            10.0
# 156                             5.0
# 157                             5.0
# 160                             5.0
# 161                             8.0
#
# [129 rows x 21 columns]

# %%
economic.drop('hf_score', axis=1, inplace=True)
economic
# Out:
#      ef_government_consumption  ef_government_transfers  \
# 0                          8.1                      7.3
# 1                          2.7                      7.8
# 2                          6.3                      8.9
# 3                          5.4                      6.3
# 4                          7.2                      7.3
# ..                         ...                      ...
# 155                        6.8                      6.0
# 156                        6.6                      5.9
# 157                        8.6                      5.8
# 160                        6.1                     10.0
# 161                        5.5                      9.3
#
#      ef_government_enterprises  ef_government_tax_income  \
# 0                          8.0                       9.0
# 1                          0.0                       7.0
# 2                          6.0                      10.0
# 3                          6.0                       7.0
# 4                          8.0                       5.0
# ..                         ...                       ...
# 155                        8.0                       5.0
# 156                        7.0                       7.0
# 157                        0.0                       7.0
# 160                        4.0                       5.0
# 161                        6.0                       4.0
#
#      ef_government_tax_payroll  ef_government_tax  ef_government_soa  \
# 0                          7.0                8.0                6.2
# 1                          2.0                4.5                2.9
# 2                          9.0                9.5                3.1
# 3                          1.0                4.0                6.9
# 4                          5.0                5.0                9.5
# ..                         ...                ...                ...
# 155                        5.0                5.0               10.0
# 156                        6.0                6.5                5.6
# 157                        6.0                6.5                2.0
# 160                        4.0                4.5                8.5
# 161                        4.0                4.0                2.7
#
#      ef_money_growth  ef_money_inflation  ef_money_currency  \
# 0                9.3                 9.6               10.0
# 1                7.0                 8.9                5.0
# 2                9.4                 3.7                5.0
# 3                5.0                 4.9               10.0
# 4                8.6                 9.8               10.0
# ..               ...                 ...                ...
# 155              9.7                 9.6               10.0
# 156              8.2                 8.8               10.0
# 157              2.8                 0.0                0.0
# 160              7.9                 8.7               10.0
# 161              9.4                 9.8                5.0
#
#      ef_trade_tariffs_revenue  ef_trade_tariffs  \
# 0                         9.6               9.0
# 1                         8.5               6.9
# 2                         9.2               7.1
# 3                         6.7               6.6
# 4                         9.0               8.6
# ..                        ...               ...
# 155                       9.5               8.4
# 156                       8.4               7.7
# 157                       8.4               7.3
# 160                       9.0               5.8
# 161                       6.2               4.8
#
#      ef_trade_regulatory_nontariff  ef_trade_regulatory_compliance  \
# 0                              6.0                             9.4
# 1                              4.8                             0.5
# 2                              4.9                             2.5
# 3                              4.6                             5.2
# 4                              5.7                             9.0
# ..                             ...                             ...
# 155                            7.0                             9.8
# 156                            5.7                             6.2
# 157                            4.1                             0.0
# 160                            5.3                             2.4
# 161                            4.8                             1.3
#
#      ef_trade_black  ef_trade_movement_foreign  ef_trade_movement_capital  \
# 0              10.0                        6.3                        5.4
# 1               0.0                        3.7                        0.0
# 2               0.0                        2.9                        3.1
# 3              10.0                        5.4                        0.8
# 4              10.0                        5.1                        5.4
# ..              ...                        ...                        ...
# 155            10.0                        7.2                        3.8
# 156            10.0                        7.0                        8.5
# 157             0.0                        3.1                        0.0
# 160            10.0                        6.9                        9.2
# 161             3.0                        3.5                        0.0
#
#      ef_trade_movement_visit  ef_trade_movement  \
# 0                        8.3                6.7
# 1                        1.1                1.6
# 2                        0.1                2.0
# 3                        8.0                4.7
# 4                       10.0                6.8
# ..                       ...                ...
# 155                      0.6                3.9
# 156                      7.7                7.7
# 157                      7.2                3.4
# 160                     10.0                8.7
# 161                      8.9                4.1
#
#      ef_regulation_credit_ownership
# 0                              10.0
# 1                               0.0
# 2                               5.0
# 3                               5.0
# 4                              10.0
# ..                              ...
# 155                            10.0
# 156                             5.0
# 157                             5.0
# 160                             5.0
# 161                             8.0
#
# [129 rows x 20 columns]

# %%
economic_2017['total'] = economic_2017.mean(axis=1)

# %%
new_df = pd.DataFrame([personal_2017['total'], political_2017['total'] , economic_2017['total']])

# %%
economic_2017.head()
# Out:
#   hf_score ef_government_consumption ef_government_transfers  \
# 0     7.84                       8.1                     7.3
# 1     4.99                       2.7                     7.8
# 2      5.4                       6.3                     8.9
# 3     6.86                       5.4                     6.3
# 4     7.42                       7.2                     7.3
#
#   ef_government_enterprises ef_government_tax_income  \
# 0                         8                        9
# 1                         0                        7
# 2                         6                       10
# 3                         6                        7
# 4                         8                        5
#
#   ef_government_tax_payroll ef_government_tax ef_government_soa  \
# 0                         7                 8               6.2
# 1                         2               4.5               2.9
# 2                         9               9.5               3.1
# 3                         1                 4               6.9
# 4                         5                 5               9.5
#
#   ef_money_growth ef_money_inflation  ... ef_trade_tariffs  \
# 0             9.3                9.6  ...                9
# 1               7                8.9  ...              6.9
# 2             9.4                3.7  ...              7.1
# 3               5                4.9  ...              6.6
# 4             8.6                9.8  ...              8.6
#
#   ef_trade_regulatory_nontariff ef_trade_regulatory_compliance ef_trade_black  \
# 0                             6                            9.4             10
# 1                           4.8                            0.5              0
# 2                           4.9                            2.5              0
# 3                           4.6                            5.2             10
# 4                           5.7                              9             10
#
#   ef_trade_movement_foreign ef_trade_movement_capital ef_trade_movement_visit  \
# 0                       6.3                       5.4                     8.3
# 1                       3.7                         0                     1.1
# 2                       2.9                       3.1                     0.1
# 3                       5.4                       0.8                       8
# 4                       5.1                       5.4                      10
#
#   ef_trade_movement ef_regulation_credit_ownership total
# 0               6.7                             10   NaN
# 1               1.6                              0   NaN
# 2                 2                              5   NaN
# 3               4.7                              5   NaN
# 4               6.8                             10   NaN
#
# [5 rows x 22 columns]

# %%
import statsmodels.api as sm

X = economic_2017['total']

y = economic_2017['hf_score']

# x_col = list(economic_2017.drop(columns='hf_score').columns)
# # Fitting the actual model

# X = sm.add_constant(X)
# model = sm.OLS(y, X, hasconst=True )

# result = model.fit()

# labels = ['intercept'] + x_col

# result.summary(xname=labels)

# %%
from sklearn.model_selection import train_test_split

# Creating subsets of the economic data
X_train_eco, X_test_eco, y_train_eco, y_test_eco = train_test_split(X, y, test_size=0.2)

# Checking shape(# of rows and cols)
display(X_train_eco.shape, X_test_eco.shape, y_train_eco.shape, y_test_eco.shape)
# Out:
# (103,)
# (26,)
# (103,)
# (26,)

# %%
# Instantiating linear regression
lr = LinearRegression()

# %%
#

# %%
new_df.T
# Out:
#         total  total  total
# 0    8.866479  6.635  8.160
# 1         NaN    NaN  3.745
# 2    5.663609    NaN  5.385
# 3    8.881006  5.855  5.675
# 4    7.583757    NaN  7.750
# ..        ...    ...    ...
# 156  9.133935  6.745  7.275
# 157  6.651775  3.935  3.860
# 158  5.892589  6.790    NaN
# 160       NaN  6.235  7.050
# 161       NaN  5.420  5.215
#
# [138 rows x 3 columns]

# %%
new_df.isna().sum()
# Out:
# 0      0
# 1      2
# 2      1
# 3      0
# 4      1
#       ..
# 156    0
# 157    0
# 158    1
# 160    1
# 161    1
# Length: 138, dtype: int64

# %%
for col in economic_2017:

    economic_2017[col] = (economic_2017[col] - economic_2017[col].mean())/economic_2017[col].std()  
    economic_2017[col]
economic_2017.head()
# Out:
#    hf_score  ef_government_consumption  ef_government_transfers  \
# 0  0.744020                   1.230487                -0.111028
# 1 -1.952806                  -1.362246                 0.135065
# 2 -1.564841                   0.366243                 0.676470
# 3 -0.183309                  -0.065879                -0.603214
# 4  0.346593                   0.798365                -0.111028
#
#    ef_government_enterprises  ef_government_tax_income  \
# 0                   0.503373                  0.724795
# 1                  -2.120269                 -0.161447
# 2                  -0.152537                  1.167916
# 3                  -0.152537                 -0.161447
# 4                   0.503373                 -1.047690
#
#    ef_government_tax_payroll  ef_government_tax  ef_government_soa  \
# 0                   0.666758           0.761482          -0.122861
# 1                  -1.227775          -0.808422          -1.747142
# 2                   1.424571           1.434297          -1.648701
# 3                  -1.606681          -1.032694           0.221684
# 4                  -0.091055          -0.584150           1.501420
#
#    ef_money_growth  ef_money_inflation  ...  ef_trade_tariffs_revenue  \
# 0         0.551627            0.423930  ...                  0.682869
# 1        -1.554780           -0.027495  ...                  0.088396
# 2         0.643210           -3.380941  ...                  0.466697
# 3        -3.386438           -2.607069  ...                 -0.884379
# 4        -0.089453            0.552909  ...                  0.358611
#
#    ef_trade_tariffs  ef_trade_regulatory_nontariff  \
# 0          1.247169                       0.343371
# 1         -0.565374                      -0.904371
# 2         -0.392751                      -0.800393
# 3         -0.824309                      -1.112328
# 4          0.901923                       0.031435
#
#    ef_trade_regulatory_compliance  ef_trade_black  ef_trade_movement_foreign  \
# 0                        0.864232        0.223201                   0.270277
# 1                       -2.182205       -5.877008                  -1.808871
# 2                       -1.497612       -5.877008                  -2.448609
# 3                       -0.573412        0.223201                  -0.449428
# 4                        0.727313        0.223201                  -0.689330
#
#    ef_trade_movement_capital  ef_trade_movement_visit  ef_trade_movement  \
# 0                   0.633400                 0.468611           0.676596
# 1                  -1.331973                -1.819748          -2.164069
# 2                  -0.203704                -2.137576          -1.941272
# 3                  -1.040807                 0.373263          -0.437391
# 4                   0.633400                 1.008918           0.732295
#
#    ef_regulation_credit_ownership
# 0                        0.881003
# 1                       -2.919979
# 2                       -1.019488
# 3                       -1.019488
# 4                        0.881003
#
# [5 rows x 21 columns]

# %%
import statsmodels.api as sm

X = economic_2017.drop(columns='hf_score').values

y = economic_2017.hf_score

x_col = list(economic_2017.drop(columns='hf_score').columns)
# Fitting the actual model

X = sm.add_constant(X)
model = sm.OLS(y, X, hasconst=True )

result = model.fit()

labels = ['intercept'] + x_col

result.summary(xname=labels)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               hf_score   R-squared:                       0.860
# Model:                            OLS   Adj. R-squared:                  0.836
# Method:                 Least Squares   F-statistic:                     35.31
# Date:                Tue, 03 Mar 2020   Prob (F-statistic):           7.37e-38
# Time:                        16:37:19   Log-Likelihood:                -55.619
# No. Observations:                 129   AIC:                             151.2
# Df Residuals:                     109   BIC:                             208.4
# Df Model:                          19
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# intercept                      -5.794e-16      0.036  -1.62e-14      1.000      -0.071       0.071
# ef_government_consumption         -0.0617      0.048     -1.278      0.204      -0.157       0.034
# ef_government_transfers           -0.0208      0.058     -0.355      0.723      -0.137       0.095
# ef_government_enterprises          0.1734      0.045      3.819      0.000       0.083       0.263
# ef_government_tax_income          -0.0038      0.052     -0.074      0.941      -0.107       0.099
# ef_government_tax_payroll         -0.0828      0.049     -1.701      0.092      -0.179       0.014
# ef_government_tax                 -0.0510      0.018     -2.894      0.005      -0.086      -0.016
# ef_government_soa                  0.1965      0.053      3.675      0.000       0.091       0.302
# ef_money_growth                    0.0118      0.045      0.262      0.794      -0.077       0.101
# ef_money_inflation                 0.0890      0.055      1.620      0.108      -0.020       0.198
# ef_money_currency                  0.1166      0.051      2.295      0.024       0.016       0.217
# ef_trade_tariffs_revenue          -0.0567      0.052     -1.096      0.275      -0.159       0.046
# ef_trade_tariffs                   0.1054      0.055      1.903      0.060      -0.004       0.215
# ef_trade_regulatory_nontariff      0.1460      0.059      2.486      0.014       0.030       0.262
# ef_trade_regulatory_compliance     0.2735      0.060      4.557      0.000       0.155       0.392
# ef_trade_black                     0.0014      0.045      0.031      0.975      -0.089       0.091
# ef_trade_movement_foreign          0.4843      0.491      0.987      0.326      -0.488       1.456
# ef_trade_movement_capital          1.0032      1.070      0.937      0.351      -1.118       3.124
# ef_trade_movement_visit            1.0516      1.225      0.858      0.393      -1.376       3.480
# ef_trade_movement                 -1.7910      2.107     -0.850      0.397      -5.966       2.384
# ef_regulation_credit_ownership     0.0967      0.047      2.065      0.041       0.004       0.190
# ==============================================================================
# Omnibus:                        2.291   Durbin-Watson:                   1.901
# Prob(Omnibus):                  0.318   Jarque-Bera (JB):                1.860
# Skew:                          -0.157   Prob(JB):                        0.395
# Kurtosis:                       3.498   Cond. No.                     3.95e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.8e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """
